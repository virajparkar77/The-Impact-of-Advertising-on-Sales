# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("C:\\Users\\Parkar\\Desktop\\Project\\Python\\Advertising.csv")
df1.head(3)
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3

# %%
df1=df1.iloc[ : , 1: ]
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
sns.displot(df2.Sales, kind='kde')

# %%
df1.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
df1.shape
# Out:
# (200, 4)

# %%
sns.boxplot(df1)
# Out:
# <Axes: >

# %%
sns.pairplot(df1, kind='scatter')

# %%
corr= df1.corr()
sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm', cbar=True)
# Out:
# <Axes: >

# %%
X1 = df1.TV
y1= df1['Sales']

# %%
 from sklearn.model_selection import train_test_split

X1_train, X1_test, y1_train, y1_test = train_test_split(X1,y1, test_size=0.3, random_state=42)

X1_train = X1_train.values.reshape(-1, 1)
X1_test = X1_test.values.reshape(-1, 1)

# %%
from sklearn.linear_model import LinearRegression

lm= LinearRegression()
lm.fit(X1_train, y1_train)
# Out:
# LinearRegression()

# %%
lm.coef_
# Out:
# array([0.0464078])

# %%
predict_Sales=lm.predict(X1_test)

# %%
sns.displot(predict_Sales - y1_test, kind='kde')

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, median_absolute_error
import math

# %%
print('MSE: ', mean_squared_error(y1_test, predict_Sales))
print('MAE: ', mean_absolute_error(y1_test, predict_Sales))
print("RMSE: ", math.sqrt(mean_squared_error(y1_test, predict_Sales)))
print("MedAE: ", median_absolute_error(y1_test, predict_Sales))
# Out:
# MSE:  8.970991242413614
# MAE:  2.2758809050205113
# RMSE:  2.9951613049072354
# MedAE:  1.6582404054863877
